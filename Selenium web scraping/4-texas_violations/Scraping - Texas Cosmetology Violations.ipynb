# %% [markdown]
# # Texas Cosmetologist Violations
#
# Texas has a system for [searching for license violations](https://www.tdlr.texas.gov/cimsfo/fosearch.asp). You're going to search for cosmetologists!

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# We'll be using Selenium for this, *not* BeautifulSoup and requests.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

# %% [markdown]
# ## Starting your search
#
# Starting from [here](https://www.tdlr.texas.gov/cimsfo/fosearch.asp), search for cosmetologist violations for people with the last name **Nguyen**.

# %%
driver = webdriver.Chrome()
driver.get('https://www.tdlr.texas.gov/cimsfo/fosearch.asp')

# %%
dropdown = Select(driver.find_element_by_name('pht_status'))
dropdown.select_by_visible_text('Cosmetologists')

# %%
last_name = driver.find_element_by_name('pht_lnm')
driver.execute_script('arguments[0].scrollIntoView(true)',last_name)
last_name.send_keys('Nguyen')

# %%
button = driver.find_element_by_xpath('//*[@id="dat-menu"]/div/div[2]/div/div/section/div/div/table/tbody/tr/td/form/table/tbody/tr[18]/td/input[1]')
driver.execute_script('arguments[0].scrollIntoView(true)',button)
button.click()

# %% [markdown]
# ## Scraping
#
# Once you are on the results page, do this.

# %% [markdown]
# ### Loop through each result and print the entire row
#
# Okay wait, that's a heck of a lot. Use `[:10]` to only do the first ten (`listname[:10]` gives you the first ten).

# %%
table = driver.find_element_by_tag_name('table')
items  = table.find_elements_by_tag_name('tr')

for item in items[:10]:
    if item == items[0]:
        continue
    else:
        print('-----------------------')
        cells = item.find_elements_by_tag_name('td')
        for cell in cells:
            print(cell.text)
# Out:
# -----------------------
# NGUYEN, TOAN HUU
# City: SAN ANTONIO
# County: BEXAR
# Zip Code: 78217
#
#
# License #(s): 780948, 1706491, 1699123
#
# Complaint # COS20180004289
# Date: 5/30/2018
#
# Respondent is assessed an administrative penalty in the amount of $500.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# -----------------------
# NGUYEN, HANH CONG
# City: EL PASO
# County: EL PASO
# Zip Code: 79934
#
#
# License #: 737708
#
# Complaint # COS20180006594
# Date: 5/30/2018
#
# Respondent is assessed an administrative penalty in the amount of $1,000.
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.
# -----------------------
# NGUYEN, KHIEM VAN
# City: LONGVIEW
# County: GREGG
# Zip Code: 75604
#
#
# License #: 731665
#
# Complaint # COS20180000257
# ...

# %% [markdown]
# ### Loop through each result and print each person's name
#
# You'll get an error because the first one doesn't have a name. How do you make that not happen?! If you want to ignore an error, you use code like this:
#
# ```python
# try:
#    try to do something
# except:
#    print("It didn't work')
# ```
#
# It should help you out. If you don't want to print anything, you can type `pass` instead of the `print` statement.
#
# **Why doesn't the first one have a name?**

# %%
for item in items:

    if item == items[0]:
        continue
    else:
        print('-----------------------')
        name = item.find_elements_by_class_name('results_text')[0]
        print(name.text)
# Out:
# -----------------------
# NGUYEN, TOAN HUU
# -----------------------
# NGUYEN, HANH CONG
# -----------------------
# NGUYEN, KHIEM VAN
# -----------------------
# NGUYEN, DIEP THI NGOC
# -----------------------
# NGUYEN, LAN T-THUY
# -----------------------
# NGUYEN, TUAN A
# -----------------------
# NGUYEN, THAO B
# -----------------------
# NGUYEN, BETH MARIA
# -----------------------
# NGUYEN, TRUNG N
# -----------------------
# NGUYEN, NGAT THI
# -----------------------
# NGUYEN, KELLY PHUONG N
# -----------------------
# NGUYEN, CHAU THI
# -----------------------
# NGUYEN, XUAN T
# -----------------------
# NGUYEN, THANH C
# -----------------------
# NGUYEN, HAI
# -----------------------
# NGUYEN, JENNIFER T
# -----------------------
# NGUYEN, TONY VAN
# -----------------------
# NGUYEN, HANH THAO TRAN
# -----------------------
# NGUYEN, QUYEN THI MAI
# -----------------------
# NGUYEN, OANH THI
# -----------------------
# NGUYEN, THU NHU
# -----------------------
# ...

# %% [markdown]
# ## Loop through each result, printing each violation description ("Basis for order")
#
# > - *Tip: You'll get an error even if you're ALMOST right - which row is causing the problem?*
# > - *Tip: You can get the HTML of something by doing `.get_attribute('innerHTML')` - it might help you diagnose your issue.*
# > - *Tip: Or I guess you could just skip the one with the problem...

# %%
for item in items[:10]:
    if item == items[0]:
        continue
    else:
        print('-----------------------')
        description = item.find_elements_by_tag_name('td')[2]
        print(description.text)
# Out:
# -----------------------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.
# -----------------------
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.
# -----------------------
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect all wax pots.
# -----------------------
# Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to disinfect multi-use equipment, implements, and tools prior to use on each client.
# -----------------------
# ...

# %% [markdown]
# ## Loop through each result, printing the complaint number
#
# - TIP: Think about the order of the elements

# %%
for item in items[:10]:
    if item == items[0]:
        continue
    else:
        print('-----------------------')
        first_cell= item.find_elements_by_tag_name('td')[0]
        complain_num = first_cell.find_elements_by_class_name('results_text')[-1]
        print(complain_num.text)
# Out:
# -----------------------
# COS20180004289
# -----------------------
# COS20180006594
# -----------------------
# COS20180000257
# -----------------------
# COS20180004915
# -----------------------
# COS20180009255
# -----------------------
# COS20140018343
# -----------------------
# COS20180008846
# -----------------------
# COS20180000897
# -----------------------
# COS20170023893

# %% [markdown]
# ## Saving the results
#
# ### Loop through each result to create a list of dictionaries
#
# Each dictionary must contain
#
# - Person's name
# - Violation description
# - Violation number
# - License Numbers
# - Zip Code
# - County
# - City
#
# Create a new dictionary for each result (except the header).
#
# > *Tip: If you want to ask for the "next sibling," you can't use `find_next_sibling` in Selenium, you need to use `element.find_element_by_xpath("following-sibling::div")` to find the next div, or `element.find_element_by_xpath("following-sibling::*")` to find the next anything.

# %%
table = driver.find_element_by_tag_name('table')
items  = table.find_elements_by_tag_name('tr')
rows = []
for item in items:
    if item == items[0]:
        continue
    else:
        
        row = {}
        
        cells = item.find_elements_by_tag_name('td')
        first_cell= cells[0]
        
        name = first_cell.find_elements_by_class_name('results_text')[0].text
        row['Person\'s name']=name
        
        description = cells[-1].text
        row['Violation Description'] = description
        
        vio_num = first_cell.find_elements_by_class_name('results_text')[-1].text
        row['Violation Number'] = vio_num
        
        lic_num = first_cell.find_elements_by_class_name('results_text')[-2].text
        row['License Number'] = lic_num
        
        city = first_cell.find_elements_by_class_name('results_text')[1].text
        row['City']=city
        
        county = first_cell.find_elements_by_class_name('results_text')[2].text
        row['County']=county
        
        zipcode = first_cell.find_elements_by_class_name('results_text')[3].text
        row['Zip Code']=zipcode
        
        rows.append(row)

# %%
rows[:10]
# Out:
# [{"Person's name": 'NGUYEN, TOAN HUU',
#   'Violation Description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.',
#   'Violation Number': 'COS20180004289',
#   'License Number': '780948, 1706491, 1699123',
#   'City': 'SAN ANTONIO',
#   'County': 'BEXAR',
#   'Zip Code': '78217'},
#  {"Person's name": 'NGUYEN, HANH CONG',
#   'Violation Description': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.',
#   'Violation Number': 'COS20180006594',
#   'License Number': '737708',
#   'City': 'EL PASO',
#   'County': 'EL PASO',
#   'Zip Code': '79934'},
#  {"Person's name": 'NGUYEN, KHIEM VAN',
# ...

# %% [markdown]
# ### Save that to a CSV
#
# - Tip: You'll want to use pandas here

# %%
import pandas as pd
df = pd.DataFrame(rows)
df
# Out:
#                City      County                     License Number  \
# 0       SAN ANTONIO       BEXAR           780948, 1706491, 1699123
# 1           EL PASO     EL PASO                             737708
# 2          LONGVIEW       GREGG                             731665
# 3           HOUSTON      HARRIS                    1347649, 760528
# 4       SAN ANTONIO       BEXAR                             767339
# 5            AUSTIN      TRAVIS                             681274
# 6            EULESS     TARRANT                    721373, 1142884
# 7           HOUSTON      HARRIS                            1470271
# 8          AMARILLO      POTTER            1196244, 767015, 767014
# 9         PITTSBURG        CAMP                             759931
# 10   CORPUS CHRISTI      NUECES                    751553, 1442491
# 11         VICTORIA    VICTORIA  749847, 1656235, 1564805, 1588030
# 12          HOUSTON      HARRIS                             765777
# ...

# %%
df.to_csv('Texas_Cosmetologist_Violations.csv',index = False)

# %% [markdown]
# ### Open the CSV file and examine the first few. Make sure you didn't save an extra weird unnamed column.

# %%
df = pd.read_csv('Texas_Cosmetologist_Violations.csv')
df.head()
# Out:
#           City   County            License Number          Person's name  \
# 0  SAN ANTONIO    BEXAR  780948, 1706491, 1699123       NGUYEN, TOAN HUU
# 1      EL PASO  EL PASO                    737708      NGUYEN, HANH CONG
# 2     LONGVIEW    GREGG                    731665      NGUYEN, KHIEM VAN
# 3      HOUSTON   HARRIS           1347649, 760528  NGUYEN, DIEP THI NGOC
# 4  SAN ANTONIO    BEXAR                    767339     NGUYEN, LAN T-THUY
#
#                                Violation Description Violation Number  \
# 0  Respondent failed to clean and sanitize whirlp...   COS20180004289
# 1  Respondent failed to clean and sanitize whirlp...   COS20180006594
# 2  Respondent failed to follow whirlpool foot spa...   COS20180000257
# 3  Respondent failed to disinfect tools, implemen...   COS20180004915
# 4  Respondent failed to clean, disinfect, and ste...   COS20180009255
#
#    Zip Code
# 0     78217
# 1     79934
# 2     75604
# 3     77014
# 4     78255
