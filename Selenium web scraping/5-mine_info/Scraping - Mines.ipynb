# %% [markdown]
# # Mine Safety
#
# We're interested in [US mine safety](https://arlweb.msha.gov/drs/drshome.htm), thank goodness we can search for these things.

# %% [markdown]
# ## Setup: Import what you'll need to search and scrape and Selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

# %% [markdown]
# ## Starting from `https://arlweb.msha.gov/drs/drshome.htm`, search for every operator with 'dirt' in their name, including abandoned mines.
#
# > - *Tip: If you can't make an element work using name, class or ID, try to use the XPath*

# %%
driver = webdriver.Chrome()
driver.get('https://arlweb.msha.gov/drs/drshome.htm')

# %%
operators = driver.find_element_by_name('OperSearch')
driver.execute_script('arguments[0].scrollIntoView(true)',operators)

# %%
operators.send_keys('dirt')

# %%
#including abandoned mine
button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table/tbody/tr[3]/td[3]/table/tbody/tr/td/input')
button.click()

# %%
#submit search 

button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table/tbody/tr[7]/td[3]/input[1]')
driver.execute_script('arguments[0].scrollIntoView(true)',button)
button.click()

# %% [markdown]
# ## Scrape the results page, saving it as `dirt-operators.csv`
#
# > - *Tip: Think about what each row in your dataset will be, and start by looping through that*
# > - *Tip: Printing is cool and good! Print everything! Move it into a dictionary later.*
# > - *Tip: If you don't want a row, think about what's in the row that makes it different. You can use an `if` statement or list slicing to skip the ones you aren't interested in.*
# > - *Tip: Make sure your dictionary and your loop variable have DIFFERENT NAMES*
# > - *Tip: After you've made your dictionary (and printed it, of course), you'll want to add it to your list of rows*
# > - *Tip: Be sure to import pandas to convert it to a dataframe*
# > - *Tip: Make sure you don't include the index when saving your dataframe*

# %% [markdown]
# ### Hopefully you know that each `tr` is supposed to be a row of your data. What is the index of the first row element that is actually a result?
#
# > - *Tip: `.text` will help you here.*
# > - *Tip: You aren't interesting in annotations or anything, just mines and where they are from*
# > - *Tip: Using `print("-----")` will help you keep track of different rows*
# > - *Tip: If you have a list called `animals`, `animals[2:]` will skip the first two and start with the third. You can use this to skip ahead to the 'good' data if you want*

# %% [markdown]
# ### Loop through each operator result, printing its name
#
# > - *Tip: If you have a list called `animals`, `animals[2:]` will skip the first two and start with the third.*
# > - *Tip: You can use list slicing or an `if` statement to skip the non-data row(s). List slicing is probably easier, even if you aren't comfortable with it.*
# > - *Tip: or honestly you can use `try` and `except` if you know how it works.*
# > - *Tip: Once you have the "right" rows of data, you're going to be looking for a certain tag inside*
# > - *Tip: Sometimes you can't say "give me this class," and instead you have to say "give me all of the `div` elements, and then give me the third one."*

# %%
table = driver.find_elements_by_tag_name('table')[4]
items  = table.find_elements_by_tag_name('tr')

rows = []

for item in items:
    
    if item == items[0]:
        continue
    else:
        
       
        tds = item.find_elements_by_tag_name('td')
        
        operator = tds[2].text
        print(operator)
# Out:
# Newberg Rock & Dirt
# Allied Dirt Moving Company
# AM Dirtworks & Aggregate Sales
# Atlas-Dirty Devil Mining
# Atlas-Dirty Devil Mining
# Babe's Dirt Work
# Bar-Lin Dirt Company
# Barber'S Dirt Pit
# Bender Sand & Dirt
# BERT'S DIRT
# Big D Dirt Service Inc
# Big Red Dirt Farm LLC
# Big River Dirt Pit
# Bob Harris Dirt Contracting
# Bohannon Sand & Dirt
# Bratcher'S Sand & Dirt
# Brewer Dirt Works
# Buck'S Dirt Pit
# C & G Dirt Hauling
# C N C Dirt Movers, Inc.
# Cambridge Dirt Sand and Gravel LLC
# Central Iowa Dirt & Demo LLC
# Crowes Trucking & Dirt Pit Services
# D & H Dirt
# Diez Dirt & Sand Hauling Inc
# Dirt Cheap
# Dirt Company
# Dirt Company
# Dirt Company
# %% [markdown]
# ### Loop through each operator result, printing its ID
#
# There should be ONE code per row, and NO empty rows between them.

# %%
mineids = driver.find_elements_by_name('search')
for mineid in mineids:
    print(mineid.text)
# Out:
# 3503598
# 0502030
# 4801789
# 4201449
# 4201450
# 1002257
# 1601167
# 4103265
# 1401575
# 1700776
# 1601251
# 0301963
# 1601082
# 3401751
# 1600916
# 3401211
# 0301267
# 1600956
# 2200033
# 0504953
# 3401929
# 1302445
# 1601106
# 3400915
# 1600983
# 4503200
# 3401266
# 3401468
# 5001797
# 4608254
# 1510279
# 2103723
# 0100776
# 4104016
# 2103914
# 4104757
# 0301729
# 0404851
# 2200734
# 5002028
# 1513393
# 3800602
# 3101630
# 3200860
# 3401762
# 2103517
# 2402626
# 2103181
# 1601124
# 1601150
# 4703427
# 0801306
# 2501216
# 3200965
# 2901371
# 2901544
# 2901709
# 4102355
# 4102420
# 4102869
# 4102951
# 4102958
# 4104876
# 3003502
# 4103258
# 3901432
# 2103556
# 1601250
# 1600908
# 1600953
# 4104185
# 2901536
# 3609624
# 3800709
# 3609931
# 1601257
# 0801275
# 1601379
# 1601380
# 1601381
# 1601134
# 1601165
# 3901042
# 1601194
# 4104054
# 4801674
# 2402474
# 1600920
# 4102955
# 4103107
# 1512530
# 1515619
# 1518318
# 4405366
# 4407196
# 1519685
# 1519799
# 4407379
# 4407003
# 2602570
# 2402503
# 4407296
# 1519273
# 4407270
# 4102682
# 0801259
# 0203332
# 0302015
# 2901986
# 1601127
# 4105017
# 1600986
# 4103324
# 4202013
# 0801417
# 0801371
# 2402115
# 4300748
# 4300768
# 4300776
# 0103209
# 1601159
# 2302283
# 4102586
# 4104475
# 3800617
# 1601234
# 4104648
# 2103518
# 1601292
# 4103429
# 4103264

# %% [markdown]
# ## Saving the results
#
# ### Loop through each `tr` to create a list of dictionaries
#
# Each dictionary must contain
#
# - Operator ID
# - Operator name
# - Mine name
# - State
# - Mine type
# - Coal or metal
# - Status
# - Commodity
#
# Create a new dictionary for each row.
#
# > - *Tip: Start with an empty dictionary, then add the keys one at a time like we did during class*
# > - *Tip: You might want to save all of the cells in a variable, then use indexes to get the second, third, fourth, etc.*
# > - *Tip: I know you already skipped a bunch of rows already, but one of them still might be bad! Which one is it? How can you skip it? You might need to slice out some of the end of your list, too. Use `print` to help you debug, or just look at the page closely.*
# > - *Tip: Or, if you did the other homework already, `try` / `except` is also an option*

# %%
table = driver.find_elements_by_tag_name('table')[4]
items  = table.find_elements_by_tag_name('tr')

rows = []

for item in items:
    
    if item == items[0]:
        continue
    else:
        print('-----------')
        
        row = {}
        
        mineid = item.find_element_by_name('search')
        print(mineid.text)
        row['ID'] = mineid.text
        
        state = item.find_element_by_tag_name('b')
        print(state.text)
        row['State'] = state.text
        
        tds = item.find_elements_by_tag_name('td')
        
        operator = tds[2].text
        print(operator)
        row['Operator'] = operator
        
        minename = tds[3].text
        print(minename)
        row['minename'] = minename
        
        types = tds[4].text
        print(types)
        row['Type'] = types
        
        cm = tds[5].text
        print(cm)
        row['Coal or Metal Mine'] = cm
        
        status = tds[6].text
        print(status)
        row['Status'] = status
        
        commodity = tds[7].text
        print(commodity)
        row['Commodity'] = commodity
        
        
        rows.append(row)
# Out:
# -----------
# 3503598
# OR
# Newberg Rock & Dirt
# Newberg Rock & Dirt
# Surface
# M
# Active
# Crushed, Broken Stone NEC
# -----------
# 0502030
# CO
# Allied Dirt Moving Company
# Allied Dirt Moving Co Pit & Plant
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# -----------
# 4801789
# ND
# AM Dirtworks & Aggregate Sales
# AM Dirtworks & Aggregate Sales
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# -----------
# 4201449
# UT
# Atlas-Dirty Devil Mining
# Unit Train Loading Facility
# Facility
# C
# Abandoned
# Coal (Bituminous)
# -----------
#
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# -----------
# 0801417
# FL
# Sand & Dirt, Inc
# Molino Pit
# Surface
# M
# Active
# Sand, Common
# -----------
# 0801371
# FL
# Sand and Dirt, Inc.
# CENTURY PIT
# Surface
# M
# Abandoned
# Sand, Common
# -----------
# 2402115
# MT
# Sierra Rock & Dirt, Inc.
# Sierra Rock & Dirt Inc
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# -----------
# 4300748
# VT
# Simpson Dirtworx llc
# Simpson Sand and Gravel
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# -----------
# 4300768
# VT
# SIMPSON DIRTWORX LLC
# Pettibone Jaw Crusher
# Surface
# M
# Intermittent
# Construction Sand and Gravel
# -----------
# 4300776
# VT
# SIMPSON DIRTWORX LLC
# Chieftan 1400
# Surface
# M
# Intermittent
# Construction Sand and Gravel
# -----------
# 0103209
# AL
# Slay'S Dirt Hauling
# SLAY PIT
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# -----------
# 1601159
# LA
# Southside Dirt Company
# Southside Dirt Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# -----------
# 2302283
# MO
# Spry's Dirt & Gravel, Inc.
# Mike's Money Pit
# Surface
# M
# Intermittent
# Construction Sand and Gravel
# -----------
# 4102586
# TX
# Stewart Dirt Pit
# Stewart Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# -----------
# 4104475
# TX
# Stewart Dirt Work, Inc.
# Stewart Dirt Work Inc - Hanna Pit
# Surface
# M
# Abandoned
# Crushed, Broken Stone NEC
# -----------
# 3800617
# SC
# Sweat'S Dirt Hauling Inc
# Highway 642 Dirt Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# -----------
# 1601234
# LA
# Toler Roe Dirt Pit
# Toler Roe Dirt Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# -----------
# 4104648
# TX
# Tres Palacios Dirt, Sand & Gravel
# La Calichera Pit
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# -----------
# 2103518
# MN
# Vogt Dirt Service
# Crusher
# Surface
# M
# Intermittent
# Construction Sand and Gravel
# -----------
# 1601292
# LA
# Watson Dirt Sand & Gravel Pit Inc
# ADDISON LEASE
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# -----------
# 4103429
# TX
# Y B Dirt & Loam
# Y B Mine
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# -----------
# 4103264
# TX
# Yarbrough Dirt Pit Inc
# Yarbrough Dirt Pit #1
# Surface
# M
# Abandoned
# Construction Sand and Gravel
# -----------
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-69-a5e206dd65b9> in <module>()
#      13         row = {}
#      14
# ---> 15         mineid = item.find_element_by_name('search')
#      16         print(mineid.text)
#      17         row['ID'] = mineid.text
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in find_element_by_name(self, name)
#     207             element = element.find_element_by_name('foo')
#     208         """
# --> 209         return self.find_element(by=By.NAME, value=name)
#     210
#     211     def find_elements_by_name(self, name):
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in find_element(self, by, value)
#     651
#     652         return self._execute(Command.FIND_CHILD_ELEMENT,
# --> 653                              {"using": by, "value": value})['value']
#     654
#     655     def find_elements(self, by=By.ID, value=None):
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     626             params = {}
#     627         params['id'] = self._id
# --> 628         return self._parent.execute(command, params)
#     629
#     630     def find_element(self, by=By.ID, value=None):
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     312         response = self.command_executor.execute(driver_command, params)
#     313         if response:
# --> 314             self.error_handler.check_response(response)
#     315             response['value'] = self._unwrap_value(
#     316                 response.get('value', None))
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"name","selector":"search"}
#   (Session info: chrome=66.0.3359.181)
#   (Driver info: chromedriver=2.40.565386 (45a059dc425e08165f9a10324bd1380cc13ca363),platform=Mac OS X 10.12.6 x86_64)

# %%
import pandas as pd
df = pd.DataFrame(rows)
df
# Out:
#     Coal or Metal Mine                       Commodity       ID  \
# 0                   M       Crushed, Broken Stone NEC   3503598
# 1                   M    Construction Sand and Gravel   0502030
# 2                   M    Construction Sand and Gravel   4801789
# 3                   C               Coal (Bituminous)   4201449
# 4                   C               Coal (Bituminous)   4201450
# 5                   M    Construction Sand and Gravel   1002257
# 6                   M    Construction Sand and Gravel   1601167
# 7                   M    Construction Sand and Gravel   4103265
# 8                   M    Construction Sand and Gravel   1401575
# 9                   M    Construction Sand and Gravel   1700776
# 10                  M    Construction Sand and Gravel   1601251
# 11                  M    Construction Sand and Gravel   0301963
# 12                  M    Construction Sand and Gravel   1601082
# 13                  M    Construction Sand and Gravel   3401751
# 14                  M    Construction Sand and Gravel   1600916
# 15                  M    Construction Sand and Gravel   3401211
# 16                  M    Construction Sand and Gravel   0301267
# 17                  M    Construction Sand and Gravel   1600956
# 18                  M                Common Clays NEC   2200033
# 19                  M    Construction Sand and Gravel   0504953
# 20                  M            Sand, Industrial NEC   3401929
# 21                  M    Construction Sand and Gravel   1302445
# 22                  M    Construction Sand and Gravel   1601106
# 23                  M    Construction Sand and Gravel   3400915
# 24                  M    Construction Sand and Gravel   1600983
# 25                  M                Common Clays NEC   4503200
# 26                  M    Construction Sand and Gravel   3401266
# 27                  M    Construction Sand and Gravel   3401468
# 28                  M    Construction Sand and Gravel   5001797
# 29                  M   Crushed, Broken Limestone NEC   4608254
# ..                 ...                             ...      ...
# 102                 C               Coal (Bituminous)   1519273
# 103                 C               Coal (Bituminous)   4407270
# 104                 M    Construction Sand and Gravel   4102682
# 105                 M    Construction Sand and Gravel   0801259
# 106                 M    Construction Sand and Gravel   0203332
# 107                 M   Crushed, Broken Limestone NEC   0302015
# 108                 M    Construction Sand and Gravel   2901986
# 109                 M    Construction Sand and Gravel   1601127
# 110                 M                    Sand, Common   4105017
# 111                 M    Construction Sand and Gravel   1600986
# 112                 M    Construction Sand and Gravel   4103324
# 113                 M    Construction Sand and Gravel   4202013
# 114                 M                    Sand, Common   0801417
# 115                 M                    Sand, Common   0801371
# 116                 M    Construction Sand and Gravel   2402115
# 117                 M    Construction Sand and Gravel   4300748
# 118                 M    Construction Sand and Gravel   4300768
# 119                 M    Construction Sand and Gravel   4300776
# 120                 M    Construction Sand and Gravel   0103209
# 121                 M    Construction Sand and Gravel   1601159
# 122                 M    Construction Sand and Gravel   2302283
# 123                 M    Construction Sand and Gravel   4102586
# 124                 M       Crushed, Broken Stone NEC   4104475
# 125                 M    Construction Sand and Gravel   3800617
# 126                 M    Construction Sand and Gravel   1601234
# 127                 M    Construction Sand and Gravel   4104648
# 128                 M    Construction Sand and Gravel   2103518
# 129                 M    Construction Sand and Gravel   1601292
# 130                 M    Construction Sand and Gravel   4103429
# 131                 M    Construction Sand and Gravel   4103264
#
#                                   Operator State         Status      Type  \
# 0                    Newberg Rock & Dirt      OR        Active    Surface
# 1             Allied Dirt Moving Company      CO     Abandoned    Surface
# 2         AM Dirtworks & Aggregate Sales      ND     Abandoned    Surface
# 3               Atlas-Dirty Devil Mining      UT     Abandoned   Facility
# 4               Atlas-Dirty Devil Mining      UT     Abandoned    Surface
# 5                       Babe's Dirt Work      ID     Abandoned    Surface
# 6                   Bar-Lin Dirt Company      LA     Abandoned    Surface
# 7                      Barber'S Dirt Pit      TX     Abandoned    Surface
# 8                     Bender Sand & Dirt      KS  Intermittent    Surface
# 9                            BERT'S DIRT      ME     Abandoned    Surface
# 10                Big D Dirt Service Inc      LA     Abandoned    Surface
# 11                 Big Red Dirt Farm LLC      AR     Abandoned    Surface
# 12                    Big River Dirt Pit      LA     Abandoned    Surface
# 13           Bob Harris Dirt Contracting      OK     Abandoned    Surface
# 14                  Bohannon Sand & Dirt      LA     Abandoned    Surface
# 15                Bratcher'S Sand & Dirt      OK     Abandoned    Surface
# 16                     Brewer Dirt Works      AR     Abandoned    Surface
# 17                       Buck'S Dirt Pit      LA     Abandoned    Surface
# 18                    C & G Dirt Hauling      MS     Abandoned    Surface
# 19               C N C Dirt Movers, Inc.      NM     Abandoned    Surface
# 20    Cambridge Dirt Sand and Gravel LLC      OK     Abandoned    Surface
# 21          Central Iowa Dirt & Demo LLC      IA     Abandoned    Surface
# 22   Crowes Trucking & Dirt Pit Services      LA     Abandoned    Surface
# 23                            D & H Dirt      OK     Abandoned    Surface
# 24          Diez Dirt & Sand Hauling Inc      LA     Abandoned    Surface
# 25                            Dirt Cheap      WA     Abandoned    Surface
# 26                          Dirt Company      OK     Abandoned    Surface
# 27                          Dirt Company      OK     Abandoned    Surface
# 28                          Dirt Company      AK  Intermittent    Surface
# 29                              Dirt Con      WV     Abandoned    Surface
# ..                                     ...   ...            ...       ...
# 102                  PB Dirt Movers Inc.      KY     Abandoned    Surface
# 103                  PB Dirt Movers, Inc      VA     Abandoned    Surface
# 104                      Peveto Dirt Pit      TX     Abandoned    Surface
# 105            Phil-Dirt Industries, Inc      FL     Abandoned    Surface
# 106                   Prescott Dirt, LLC      AZ  Intermittent    Surface
# 107                      R & R Dirtworks      AR     Abandoned    Surface
# 108        R D Blankenship Dirt Work LLC      NM        Active    Surface
# 109                  Reeves Dirt Pit Inc      LA     Abandoned    Surface
# 110                    River Bottom Dirt      TX     Abandoned    Surface
# 111                       Roe'S Dirt Pit      LA     Abandoned    Surface
# 112        Russell Trest-Dirt Contractor      TX     Abandoned    Surface
# 113            S J Stahr Dirt Movers Inc      UT     Abandoned    Surface
# 114                     Sand & Dirt, Inc      FL        Active    Surface
# 115                  Sand and Dirt, Inc.      FL     Abandoned    Surface
# 116             Sierra Rock & Dirt, Inc.      MT     Abandoned    Surface
# 117                 Simpson Dirtworx llc      VT     Abandoned    Surface
# 118                 SIMPSON DIRTWORX LLC      VT  Intermittent    Surface
# 119                 SIMPSON DIRTWORX LLC      VT  Intermittent    Surface
# 120                  Slay'S Dirt Hauling      AL     Abandoned    Surface
# 121               Southside Dirt Company      LA     Abandoned    Surface
# 122           Spry's Dirt & Gravel, Inc.      MO  Intermittent    Surface
# 123                     Stewart Dirt Pit      TX     Abandoned    Surface
# 124              Stewart Dirt Work, Inc.      TX     Abandoned    Surface
# 125             Sweat'S Dirt Hauling Inc      SC     Abandoned    Surface
# 126                   Toler Roe Dirt Pit      LA     Abandoned    Surface
# 127    Tres Palacios Dirt, Sand & Gravel      TX     Abandoned    Surface
# 128                    Vogt Dirt Service      MN  Intermittent    Surface
# 129    Watson Dirt Sand & Gravel Pit Inc      LA     Abandoned    Surface
# 130                      Y B Dirt & Loam      TX     Abandoned    Surface
# 131               Yarbrough Dirt Pit Inc      TX     Abandoned    Surface
#
#                               minename
# 0                  Newberg Rock & Dirt
# 1    Allied Dirt Moving Co Pit & Plant
# 2       AM Dirtworks & Aggregate Sales
# 3          Unit Train Loading Facility
# 4    Blackie Surface Mine & Prep Plant
# 5                       Hitt Pit, Inc.
# 6                     Bar-Lin Dirt Pit
# 7                    Barber'S Dirt Pit
# 8                   BENDER SAND & DIRT
# 9                          BERT'S DIRT
# 10                       Dorothy V Pit
# 11                   Big Red Dirt Farm
# 12                  Big River Dirt Pit
# 13                          Harris Pit
# 14                BOHANNON SAND & DIRT
# 15                         Eubanks Pit
# 16                          Brewer Pit
# 17                     Buck'S Dirt Pit
# 18                 Laurel Brick & Tile
# 19                       Foster Canyon
# 20                        Cambridge #1
# 21                           Woolstock
# 22                     Crowes Dirt Pit
# 23                          D & H Dirt
# 24                  Amite Acres Dredge
# 25                          Dirt Cheap
# 26                              Pit #1
# 27                           Hicks Pit
# 28                          Bush Pilot
# 29                     Hog Lick Quarry
# ..                                 ...
# 102                      Blair Face Up
# 103                 Surface Mine No. 1
# 104                         Peveto Pit
# 105                             PIT #1
# 106                    Sandretto Drive
# 107                     Martins Quarry
# 108          R D BLANKENSHIP DIRT WORK
# 109       Reeves Dirt Pit Incorporated
# 110                  River Bottom Dirt
# 111                     Roe'S Dirt Pit
# 112                     Pine Ridge Pit
# 113             Stahr Portable Crusher
# 114                         Molino Pit
# 115                        CENTURY PIT
# 116             Sierra Rock & Dirt Inc
# 117            Simpson Sand and Gravel
# 118              Pettibone Jaw Crusher
# 119                      Chieftan 1400
# 120                           SLAY PIT
# 121                 Southside Dirt Pit
# 122                   Mike's Money Pit
# 123                        Stewart Pit
# 124  Stewart Dirt Work Inc - Hanna Pit
# 125               Highway 642 Dirt Pit
# 126                 Toler Roe Dirt Pit
# 127                   La Calichera Pit
# 128                            Crusher
# 129                      ADDISON LEASE
# 130                           Y B Mine
# 131              Yarbrough Dirt Pit #1
#
# [132 rows x 8 columns]

# %% [markdown]
# ### Save that to a CSV named `dirt-operators.csv`

# %%
df.to_csv('dirt-operators.csv',index = False)

# %% [markdown]
# ### Open the CSV file and examine the first few.
#
# Make sure you didn't save that extra weird unnamed index column.

# %%
df = pd.read_csv('dirt-operators.csv')
df.head()
# Out:
#   Coal or Metal Mine                      Commodity       ID  \
# 0                 M      Crushed, Broken Stone NEC   3503598
# 1                 M   Construction Sand and Gravel    502030
# 2                 M   Construction Sand and Gravel   4801789
# 3                 C              Coal (Bituminous)   4201449
# 4                 C              Coal (Bituminous)   4201450
#
#                            Operator State      Status      Type  \
# 0             Newberg Rock & Dirt      OR     Active    Surface
# 1      Allied Dirt Moving Company      CO  Abandoned    Surface
# 2  AM Dirtworks & Aggregate Sales      ND  Abandoned    Surface
# 3        Atlas-Dirty Devil Mining      UT  Abandoned   Facility
# 4        Atlas-Dirty Devil Mining      UT  Abandoned    Surface
#
#                             minename
# 0                Newberg Rock & Dirt
# 1  Allied Dirt Moving Co Pit & Plant
# 2     AM Dirtworks & Aggregate Sales
# 3        Unit Train Loading Facility
# 4  Blackie Surface Mine & Prep Plant
